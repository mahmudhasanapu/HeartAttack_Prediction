# %% [markdown]
# Group:6
# Group members:
# 2018-2-80-060:	Sumsun Naher Supti
# 2019-3-80-013:	Mahmud Hasan Apu
# 2018-3-80-029 :	Rudra Dey

# %%
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from matplotlib import pyplot as plt
pd.set_option('display.max_columns', None)

# %% [markdown]
# #Data collection and loading.

# %%
df = pd.read_csv('framingham.csv')
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %% [markdown]
# #Data exploration and Basic Check

# %%
df.dtypes
# Out:
# male                 int64
# age                  int64
# education          float64
# currentSmoker        int64
# cigsPerDay         float64
# BPMeds             float64
# prevalentStroke      int64
# prevalentHyp         int64
# diabetes             int64
# totChol            float64
# sysBP              float64
# diaBP              float64
# BMI                float64
# heartRate          float64
# glucose            float64
# TenYearCHD           int64
# dtype: object

# %%
df.TenYearCHD.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df.TenYearCHD.value_counts()

# %% [markdown]
# #Data Visualization
# Check whether data is balanced or not
# Databalanced: Equal number of related to binary TenYearCHD 0-(No) and 1-(Yes)

# %%
sns.countplot(x=df.TenYearCHD)
plt.xlabel('TenYearCHD')
plt.ylabel('Count')
plt.title('Count Plot of TenYearCHD')
# Out:
# Text(0.5, 1.0, 'Count Plot of TenYearCHD')

# %% [markdown]
# #Univariate analyis

# %%
plt.figure(figsize=(10, 5),facecolor="white")
plotNumber = 1

for colum in df:
    if plotNumber <=16:
        ax = plt.subplot(4,4, plotNumber)
        sns.histplot(x=df[colum],kde=True)
        plt.xlabel(colum, fontsize=10)
        plt.ylabel("count", fontsize=10)
    plotNumber +=1
plt.tight_layout()

# %%
df['TenYearCHD'].value_counts()

# %% [markdown]
# #Check for outliers
# Few columns are discrete and for few we have outliers.

# %%
plt.figure(figsize=(10,10))

plotnumber=1
for column in df:
    plt.subplot(4,4,plotnumber)
    sns.boxplot(x=df[column])
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# #Bivariate analysis
# Heart attacks chances increases, for uneducated, male, smokers and othes based on the graph.

# %%
plt.figure(figsize=(10,10))

plotnumber=1
for column in df:
    plt.subplot(4,4,plotnumber)
    sns.lineplot(y=df[column],x=df['TenYearCHD'])
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# #Feature enginnering
# visually inspecting the correlation between different variables in the DataFrame.

# %%
plt.figure(figsize=(20,20))
corr=df.corr()
a=sns.heatmap(corr,annot=True,linecolor='white',linewidths=2,cbar=True,square=True)
a

# %% [markdown]
# #Data preprocessing
# null removing by doing median.

# %%
#education
median=df['education'].median()
df.loc[df['education'].isnull() == True, 'education'] = df['education'].median()

#cigsPerDay
median=df['cigsPerDay'].median()
df.loc[df['cigsPerDay'].isnull() == True, 'cigsPerDay'] = df['cigsPerDay'].median()

#BPMeds
median=df['BPMeds'].median()
df.loc[df['BPMeds'].isnull() == True, 'BPMeds'] = df['BPMeds'].median()

#totChol
median = df['totChol'].median()
df.loc[df['totChol'].isnull() == True, 'totChol'] = df['totChol'].median()

#BMI
median = df['BMI'].median()
df.loc[df['BMI'].isnull() == True, 'BMI'] = df['BMI'].median()

#heartRate
median = df['heartRate'].median()
df.loc[df['heartRate'].isnull() == True, 'heartRate'] = df['heartRate'].median()

#glucose
median = df['glucose'].median()
df.loc[df['glucose'].isnull() == True, 'glucose'] = df['glucose'].median()

print(df.isnull().sum())

# %%
df.duplicated().sum()

# %% [markdown]
# #check the outliers again.

# %%
plt.figure(figsize=(10,5),facecolor='white')
plotnumber=1
for column in df.drop('TenYearCHD',axis=1):
    if plotnumber<=16:
        ax=plt.subplot(4,4,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=10)
        plt.ylabel('count',fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# #Data_preprocessing using minmaxscaler

# %%
from sklearn.preprocessing import MinMaxScaler
scaling = MinMaxScaler()
output = ['TenYearCHD']
data1 = scaling.fit_transform(df.drop(output,axis=1))
data1

# %%
data2 = pd.DataFrame(data1, columns=['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds','prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP','diaBP', 'BMI', 'heartRate', 'glucose'])
data2

# %%
output1 = df[['TenYearCHD']]
output1

# %%
new_data = pd.concat([data2, output1], axis=1)
new_data

# %%
x=new_data.drop('TenYearCHD',axis=1)
y=new_data[['TenYearCHD']]
x,y

# %% [markdown]
# #Model building and training
# model_LogisticRegression

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=2)
x_train,x_test,y_train,y_test

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train,y_train)

# %%
y_pred=model.predict(x_test)
y_pred

# %%
d1=pd.DataFrame(y_pred,columns=['y_pred'])
d1

# %%
model.score(x_test,y_test)

# %%
output=y_test.copy()
output['y_pred']=y_pred
output

# %% [markdown]
# #Performence evulation of the Model
# confusion_matrix,accuracy_score,f1_score,classification_report,precision_score,recall_score

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,f1_score,classification_report,precision_score,recall_score
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(precision_score(y_test,y_pred))
print(f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred))

# %% [markdown]
# Conclusion:
# For this dataset we are predicting the heart attack chances in the next 10 years of various ages of peoples. We get 15 features for this dataset. We preprocess the dataset to develop a logistic regression model. We had some feature engineering and visualized the data using pandas and matplotlib and the sns. We are using logistic regression from Sklearn for model development.
#
# After developing our model, we can see that,
# .The model has high accuracy which is 84%, but it seems to struggle with the recall for class 1 (heart attack occurrences).
#
# .Precision for class 1 is relatively low, indicating that among the predicted positive instances, only about 62% are true positives.
#
# .The F1-score is low for class 1, reflecting the trade-off between precision and recall.
#
# The evaluation results suggest a need for refinement in various aspects of the model. Enhancements could focus on data preprocessing, feature engineering, and model tuning. Balancing class representation, selecting relevant features, and exploring alternative algorithms may contribute to better predictive performance. Additionally, attention to interpretability, ethical considerations, and ongoing model monitoring could further strengthen the overall quality and reliability of the predictive system.
